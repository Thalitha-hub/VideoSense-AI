# %%
# %run 05_demo_interface_v5_improved
# Out:
# ✅ Dataset: (31998, 12)
# Loading embedding model (startup, one-time)...
# ✅ Embedding model ready.
#
# ...
#   VideoSense AI — v5 (ToT + CoT + Category-Adaptive)
# ...
#   Dataset  : 31,998 comments, 307 videos
#   Analyzed : 60 video(s)
# ...
#   → http://127.0.0.1:7860
#
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
#   [1/7] 📥 Fetching comments from YouTube (up to 350)...
#   [2/7] 🧹 Cleaning 350 comments...
#     → 280 comments after cleaning
#   [3/7] 💾 Updating dataset + FAISS index...
#   [4/7] 🌳 Running 5 agents in parallel (ToT + CoT)...
